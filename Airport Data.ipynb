# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("Excel/Airport Data Analysis_CM.xlsx")

# %%
df
# Out:
#       DayOfMonth  DayOfWeek   Carrier Origin       OriginCity Dest  \
# 0             15          6  American    JFK     New York, NY  MIA
# 1             11          2  American    CLT    Charlotte, NC  DFW
# 2             30          7  American    DCA   Washington, DC  MIA
# 3             12          3  American    MIA        Miami, FL  STX
# 4             13          4  American    MIA        Miami, FL  BDL
# ...          ...        ...       ...    ...              ...  ...
# 1045          28          5  Frontier    LGA     New York, NY  ATL
# 1046           2          7  Hawaiian    LAX  Los Angeles, CA  OGG
# 1047           9          7  Hawaiian    SEA      Seattle, WA  HNL
# 1048           9          7  Hawaiian    LIH        Lihue, HI  OGG
# 1049          30          7  American    MSP  Minneapolis, MN  DFW
#
#                    DestCity  DepartureDelay  ArrivalDelay  SchdElapsedTime  \
# 0                 Miami, FL              73            58              213
# ...
